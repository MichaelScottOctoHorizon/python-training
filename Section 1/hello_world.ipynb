# %%
#A simple reusable python function that displays "Hello World" or any form of text passed into it as a parameter

# %%
def display_message(message):
    print(message)

display_message("Hello World")
